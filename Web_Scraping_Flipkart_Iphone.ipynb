# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

my_url='https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
uClient= uReq(my_url)
page_html = uClient.read()
uClient.close()
page_soup= soup(page_html, "html.parser")

containers = page_soup.findAll("div",{"class": "_2kHMtA"})


# how many result found in the page that is 24
#print(len(containers))

# select the first product from 24 product list in the first page
#print(soup.prettify(containers[0]))

container= containers[0]


'''
print(container.div.img["alt"])             #scraping the name of the product

price = container.findAll("div",{"class": "col col-5-12 nlI3QM"})
print(price[0].text)
rating_reviews= container.findAll("div",{"class" : "gUuXy-"})
print(rating_reviews[0].text)
'''


#load all the data in a csv file

filename ="Apple_iphone_data.csv"
f= open(filename,"w")
headers= "Product_name,Pricing, Rating\n"
f.write(headers)



for container in containers:
  product_name = container.div.img["alt"]
  price_container= container.findAll("div",{"class": "col col-5-12 nlI3QM"})
  price = price_container[0].text.strip()
  rating_container= container.findAll("div",{"class" : "gUuXy-"})
  rating= rating_container[0].text
  '''
  print("Product_name:" +product_name)
  print("Price:"+price)
  print("rating:" +rating)
  '''

  #string prasing
  trim_price= ''.join(price.split())
  rm_rupee= trim_price.split("₹")
  add_rs_price ="Rs." +rm_rupee[1]
  split_price =add_rs_price.split('E')
  final_price = split_price[0]


  split_rating =rating.split(" ")
  final_rating = split_rating[0]

  print(product_name.replace(",", "|")+ ","+ final_price + "," + final_rating + "\n")
  f.write(product_name.replace(",", "|")+ ","+ final_price + "," + final_rating + "\n")

f.close()
# Out:
# Apple iPhone XR (Black| 64 GB) (Includes EarPods| Power Adapter),Rs.44,900,4.658,305
#
# Apple iPhone SE (Black| 64 GB) (Includes EarPods| Power Adapter),Rs.35,900,4.575,918
#
# Apple iPhone XR (White| 64 GB) (Includes EarPods| Power Adapter),Rs.44,900,4.658,305
#
# Apple iPhone XR (Black| 128 GB) (Includes EarPods| Power Adapter),Rs.49,900,4.658,305
#
# Apple iPhone SE (White| 64 GB) (Includes EarPods| Power Adapter),Rs.35,900,4.575,918
#
# Apple iPhone XR ((PRODUCT)RED| 64 GB) (Includes EarPods| Power Adapter),Rs.44,900,4.658,305
#
# Apple iPhone SE (Red| 64 GB) (Includes EarPods| Power Adapter),Rs.35,900,4.575,918
#
# Apple iPhone XR (Coral| 64 GB) (Includes EarPods| Power Adapter),Rs.44,900,4.658,305
#
# Apple iPhone XR (White| 128 GB) (Includes EarPods| Power Adapter),Rs.49,900,4.658,305
#
# Apple iPhone XR (Blue| 64 GB) (Includes EarPods| Power Adapter),Rs.44,900,4.658,305
#
# Apple iPhone XR ((PRODUCT)RED| 128 GB) (Includes EarPods| Power Adapter),Rs.49,900,4.658,305
#
# ...
